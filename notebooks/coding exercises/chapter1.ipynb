# %%
from pathlib import Path

# %%
app_path = Path(".").resolve().parents[1] / "app"
app_path
# Out:
# PosixPath('/Users/marcospereira/Documents/devbutter/apple_health_export/app')

# %%
project_files = [
    str(p).split("apple_health_export/")[1]
    for p in app_path.glob(pattern="**/*.py")
]
project_files
# Out:
# ['app/main.py',
#  'app/insights/__init__.py',
#  'app/parsers/streamer.py',
#  'app/parsers/__init__.py',
#  'app/config/__init__.py',
#  'app/config/logger.py',
#  'app/config/settings.py',
#  'app/pipelines/__init__.py',
#  'app/models/__init__.py',
#  'app/models/health_record_model.py',
#  'app/db/__init__.py']

# %%
list(app_path.glob(pattern="*.py"))
# Out:
# [PosixPath('/Users/marcospereira/Documents/devbutter/apple_health_export/app/main.py'),
#  PosixPath('/Users/marcospereira/Documents/devbutter/apple_health_export/app/insights/__init__.py'),
#  PosixPath('/Users/marcospereira/Documents/devbutter/apple_health_export/app/parsers/streamer.py'),
#  PosixPath('/Users/marcospereira/Documents/devbutter/apple_health_export/app/parsers/__init__.py'),
#  PosixPath('/Users/marcospereira/Documents/devbutter/apple_health_export/app/config/__init__.py'),
#  PosixPath('/Users/marcospereira/Documents/devbutter/apple_health_export/app/config/logger.py'),
#  PosixPath('/Users/marcospereira/Documents/devbutter/apple_health_export/app/config/settings.py'),
#  PosixPath('/Users/marcospereira/Documents/devbutter/apple_health_export/app/pipelines/__init__.py'),
#  PosixPath('/Users/marcospereira/Documents/devbutter/apple_health_export/app/models/__init__.py'),
# ...

# %%
# Out:
# <generator object Path.walk at 0x10a3d8e00>
